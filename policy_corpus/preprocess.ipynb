# %% [markdown]
# # Drive and Frameworks Setup

# %%
# connect with gdrive
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive

# connect with "DPI Summer Interns 2024" folder
# !ls "/content/drive/MyDrive/DPI Summer Interns 2024/Hassan/MultiLangPolicyScanner/policy_corpus"

# connect with "DPI Summer Interns 2024" folder
# %cd /content/drive/MyDrive/DPI Summer Interns 2024/Hassan/MultiLangPolicyScanner/policy_corpus
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/.shortcut-targets-by-id/1O7dDY06zyuGFOPs6tPr05M2GKlVoONFs/DPI Summer Interns 2024/Hassan/MultiLangPolicyScanner/policy_corpus

# %%
# Install necessary libraries
# !pip3 install konlpy
# !pip3 install hanzidentifier
# !pip3 install sudachipy
# !pip3 install sudachidict_full #this one takes a sec
# !pip3 install preprocess
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.1)
# Requirement already satisfied: hanzidentifier in /usr/local/lib/python3.10/dist-packages (1.2.0)
# Requirement already satisfied: zhon~=2.0 in /usr/local/lib/python3.10/dist-packages (from hanzidentifier) (2.0.2)
# Requirement already satisfied: sudachipy in /usr/local/lib/python3.10/dist-packages (0.6.8)
# Requirement already satisfied: sudachidict_full in /usr/local/lib/python3.10/dist-packages (20240409)
# Requirement already satisfied: SudachiPy<0.7,>=0.5 in /usr/local/lib/python3.10/dist-packages (from sudachidict_full) (0.6.8)
# Requirement already satisfied: preprocess in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from preprocess) (0.18.3)

# %%
# Import necessary libraries

#general
import pandas as pd
import os
import re
import glob
import regex
import difflib
import nltk
import sys
from tqdm.notebook import tqdm
import preprocess

#cprofile
import cProfile
import pstats
from pstats import SortKey

#japanese
import sudachipy

#korean
from konlpy.tag import Okt

#chinese
import jieba
import hanzidentifier

# %% [markdown]
# # Lists of Language Files

# %%
# read privacy_links_df.csv into a dataframe
privacy_links_df = pd.read_csv('privacy_links_df_updated.csv')
japanese_privacy_links_df = pd.read_csv('language_policy_links/JP_privacy_links_top_1000(Corrected).csv')
# privacy_links_df['valid_language']
# print(privacy_links_df[privacy_links_df['policy_downloaded'] == True]['init_language'].value_counts())
# print(privacy_links_df[privacy_links_df['policy_downloaded'] == True]['valid_language'].value_counts())

ja_policy_list = japanese_privacy_links_df['hash'].tolist() # modify to read the ~1200 or so links
ko_policy_list = privacy_links_df[(privacy_links_df['policy_downloaded'] == True) & (privacy_links_df['valid_language'] == 'ko')]['hash'].tolist()
chinesese_policy_list = privacy_links_df[(privacy_links_df['policy_downloaded'] == True) & (privacy_links_df['valid_language'] == 'zh-cn')]['hash'].tolist()
chinesese_policy_list.extend(privacy_links_df[(privacy_links_df['policy_downloaded'] == True) & (privacy_links_df['valid_language'] == 'zh-tw')]['hash'].tolist())

print(f"Total japanese files {len(ja_policy_list)}")
print(f"Total korean files {len(ko_policy_list)}")
print(f"Total chinese files {len(chinesese_policy_list)}")
# Out:
# Total japanese files 1297
# Total korean files 916
# Total chinese files 428

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Japanese Helper Function

# %%
def is_kana(text : str):
    return bool(regex.search(r'\P{Script=Katakana}|\P{Script=Hiragana}', text))

def clean_japanese_text(text : str):
    text = text.strip()
    text = re.sub(r'\s+',' ',text) #collapse white space
    text = re.sub(r'[\n\r]+','\n',text) #collapse new lines
    text = re.sub(r'，|,', '、', text) #normalize commas
    text = re.sub(r'\.', '。', text) #normalize periods

    return text

# %%
print(is_kana("あa"))
# Out:
# True

# %%
#readablity
def japanese_readability_index(tokens : pd.DataFrame, scale : int = 1): #modified to take already tokenized text
  """Overview
  --
  Calculates readabilty for korean texts with formula:
    (total_words + total_syllables) / sentences

  Parameters
  --
  tokens : pandas DataFrame containing text as tokenized by the function "tokenize_korean"
  scale : scale factor to multipy readability score, used for standardizing score between langagues

  Returns
  --
  int
      kri score, if failed returns as -1
  """

  # counts number of periods to get # of sentences (rough approximation)
  try: #wrapped in try in case of no periods
    sentences = tokens["POS2"].value_counts()["句点"]
  except:
    return(-1) # if contains no periods, readability score is junk, return -1

  #remove periods and commas from word count (should be only remaining punctuation)
  mask = (tokens["POS2"] == '句点') | (tokens["POS2"] == '読点')
  words = tokens.drop(tokens[mask].index, inplace = False)['Reading'].to_list()

  total_words = len(words) #not perfect but morphs ~approx words
  total_syllables = sum(len(word) for word in words)

  # Calculate the KRI score
  jri_score = (total_words + total_syllables) / sentences

  return jri_score

# %%
def remove_stop_word_japanese(tokens : pd.DataFrame, stopwords : set()): #takes already tokenized text
  """Overview
  --
  Removes stopwords passed to function from tokenized text

  Parameters
  --
  tokens : pandas DataFrame containing text as tokenized by the function "tokenize_korean"
  stopwords : set of stopwords as string

  Returns
  --
  void
      deletes stopwords inplace on tokens
  """

  mask = tokens["Normalized"].isin(stopwords)
  tokens.drop(tokens[mask].index, inplace = True)#drop is performed in place, not returned

def remove_white_space_japanese(tokens : pd.DataFrame): #takes already tokenized text
  """Overview
  --
  Removes stopwords passed to function from tokenized text

  Parameters
  --
  tokens : pandas DataFrame containing text as tokenized by the function "tokenize_korean"

  Returns
  --
  void
      deletes white-space inplace on tokens
  """
  mask = (tokens["POS1"] == "空白")
  tokens.drop(tokens[mask].index, inplace = True)#drop is performed in place, not returned

def remove_punc_japanese(tokens : pd.DataFrame, keep_periods = True, keep_commas = True): #takes already tokenized text
  """Overview
  --
  Removes punctuation from tokenized text

  Parameters
  --
  tokens : pandas DataFrame containing text as tokenized by the function "tokenize_korean"
  keep_periods : if true, periods aren't removed
  keep_commas : if true, commas aren't removed

  Returns
  --
  void
      deletes punctuation inplace on tokens
  """

  #unrecognized_punc = {} #in case some puncutuation is not marked as punctuation (unused)
  mask = (tokens["POS1"] == '"補助記号"')

  #used to keep periods and commas
  if keep_periods:
    mask = mask & (tokens["POS2"] != '句点')
  if keep_commas:
    mask = mask & (tokens["POS2"] != '読点')

  #removes unrecognized punc (unused)
  #mask = mask | (tokens["normalized"].isin(unrecognized_punc))

  tokens.drop(tokens[mask].index, inplace = True)#drop is performed in place, not returned

# %%
def formatter_japanese(tokens : list[sudachipy.MorphemeList]):
  formatted = []
  for morph_list in tokens: #due to quirk of morpheme_list - loop over each morpheme list
    for token in morph_list: #loops over tokens - each token is a new row

      #spliting on splitmode A
      a_split = [sub_token.surface() for sub_token in token.split(sudachipy.SplitMode.A, add_single = False)] #split tuple of morphemes into list of strings
      if len(a_split) == 0:
          a_split = "*" #matches SudachiPy na value
      else:
          a_split = "-".join(a_split)

      #spliting on splitmode B
      b_split = [sub_token.surface() for sub_token in token.split(sudachipy.SplitMode.B, add_single = False)] #split tuple of morphemes into list of strings
      if len(b_split) == 0:
          b_split = "*" #matches SudachiPy na value
      else:
          b_split = "-".join(b_split)

      pos = token.part_of_speech()
      formatted.append((token.surface(),token.normalized_form(),token.reading_form(),token.dictionary_form(),pos[0],pos[1],pos[2],pos[3],pos[4],pos[5],token.is_oov(),b_split,a_split))

  return formatted

# %%
def safe_split(text : str, tokenizer : sudachipy.Tokenizer):
  try:
    #attemps to tokenize text
    return [tokenizer.tokenize(text)] #returns in a list since morpheme lists dont support extension/appending
  except:
    #checks if error is due to oversized input
    if(sys.getsizeof(text) > 49149):

        #try to split by paragraph
        split = re.split(r'(\n)', text)

        #if no obvious paragraphs are found, split along sentence boundaries
        if len(split) <= 1:
          split = re.split(r'(\.|。)', text)

          #if no obvious sentence boundaries are found, split between words
          if len(split) <= 1:
            split = re.split(r'(\w|,|、|，)', text)

            #if still no good split is found, throw an exception
            if len(split)  <= 1:
              raise("String is oversized and a valid split wasn't found.")

        #splits text at middle split point
        mid = len(split) // 2
        first_half = "".join(split[0:mid])
        back_half = "".join(split[mid:])

        #recursively tokenizes smaller halves
        first_half_split = safe_split(first_half, tokenizer)
        back_half_split = safe_split(back_half, tokenizer)

        #recombines and returns section as list of morpheme lists
        first_half_split.extend(back_half_split)
        return first_half_split

    else:
        raise("something is wrong, check SudachiPY exception.")

#tokenization helper function
def tokenize_japanese(text : str, tokenizer : sudachipy.Tokenizer):
    """Tokenization helper function

    Parameters
    ----------
    text : The text to tokenize
    tokenizer : The SudachiPy tokenizer to use

    Returns
    -------
    void
        Creates file at the file location specified
    """

    #use recursive safe split to split text greater than SudachiPy size limit
    tokens = safe_split(text, tokenizer)

    data = formatter_japanese(tokens)

    return pd.DataFrame(data, columns=["Surface","Normalized","Reading","Dictionary","POS1","POS2","POS3","POS4","Conj_Type","Conj","OOV","B_Split","A_Split"])

def mass_tokenize_japanese(hash_list : list, in_folder : str, out_folder : str, stopwords : set = {}, readability : bool = True):
  """Overview
  --
  Tokenizes all files listed in hash list and corresponding text file

  Parameters
  --
  hash_list : list of hashes to tokenize
  in_folder : folder to look for txt files using hash as name
  out_folder : folder to write tokenized text csv files into
  stopwords : set of stopword to remove from all texts
  readability : if true, also writes csv with each files readability score as calculated by "korean_readability_index"

  Returns
  --
  void
      writes CSV files to out_folder
  """

  #ensures out_folder exists
  if not os.path.exists(out_folder):
      os.makedirs(out_folder)

  #create dictionary - Using full for best performance
  full_dict = sudachipy.Dictionary(dict = "full")
  #create tokenizer - Spliting on highest level for NER
  tokenizer_C = full_dict.create(mode = sudachipy.SplitMode.C)

  if readability:
    r_scores = [] #list for storing readability scores

  #iterate over every file in has list
  for hash in tqdm(hash_list):
    #open and clean text
    with open(f"{in_folder}/{hash}.txt", "r") as f:
      text = f.read()
      text = clean_japanese_text(text)

      #kana check check
      if is_kana(text):
        tokens = tokenize_japanese(text, tokenizer_C) #tokenization

        #first rount of stopwording, remove superflous puncuation and white-space
        remove_punc_japanese(tokens)
        remove_white_space_japanese(tokens)

        #caluclate readabilty
        if readability:
          readability_score = japanese_readability_index(tokens)

          #if caluclating readabilty fails and return as -1, print hash
          if readability_score == -1:
            print(hash)

          r_scores.append(readability_score)

        #second rount of stopwording, remove actual stopwords
        remove_stop_word_japanese(tokens, stopwords = stopwords)

        # write to ./korean_preprocess
        tokens.to_csv(f"{out_folder}/{hash}.csv", index=False)

  #write readability with coresponding hash
  if readability:
    data = zip(hash_list,r_scores)
    r_scores_df = pd.DataFrame(data, columns = ["hash","readability"])
    r_scores_df.to_csv(f"{out_folder}/readability.csv", index=False)

# %% [markdown]
# ## Korean Helper Functions

# %%
#simple language check if text contains hangul character
def is_hangul(text : str):
    return bool(regex.search(r'\p{IsHangul}', text))

#simple text cleaner to normalize text input
def clean_korean_text(text : str):
    text = text.strip()
    text = re.sub(r'[\n\r\s]+',' ',text) #new lines arent use for splitting so simply converted to whitespace
    text = re.sub(r'，|、', ',', text) #normalize commas
    text = re.sub(r'。', '.', text) #normalize periods

    return text

# %%
#readablity
def korean_readability_index(tokens : pd.DataFrame, scale : int = 1): #modified to take already tokenized text
  """Overview
  --
  Calculates readabilty for korean texts with formula:
    (total_words + total_syllables) / sentences

  Parameters
  --
  tokens : pandas DataFrame containing text as tokenized by the function "tokenize_korean"
  scale : scale factor to multipy readability score, used for standardizing score between langagues

  Returns
  --
  int
      kri score, if failed returns as -1
  """

  # counts number of periods to get # of sentences (rough approximation)
  try: #wrapped in try in case of no periods
    sentences = tokens['normalized'].value_counts()["."]
  except:
    return(-1) # if contains no periods, readability score is junk, return -1

  #remove periods and commas from word count (should be only remaining punctuation)
  mask = (tokens["normalized"] == '.') | (tokens["normalized"] == ',')
  words = tokens.drop(tokens[mask].index, inplace = False)['normalized'].to_list()

  total_words = len(words) #not perfect but morphs ~approx words
  total_syllables = sum(len(word) for word in words)

  # Calculate the KRI score
  kri_score = (total_words + total_syllables) / sentences

  return kri_score

# %%
def remove_stop_word_korean(tokens : pd.DataFrame, stopwords : set()): #takes already tokenized text
  """Overview
  --
  Removes stopwords passed to function from tokenized text

  Parameters
  --
  tokens : pandas DataFrame containing text as tokenized by the function "tokenize_korean"
  stopwords : set of stopwords as string

  Returns
  --
  void
      deletes stopwords inplace on tokens
  """

  mask = tokens["normalized"].isin(stopwords)
  tokens.drop(tokens[mask].index, inplace = True)#drop is performed in place, not returned

def remove_punc_korean(tokens : pd.DataFrame, keep_periods = True, keep_commas = True): #takes already tokenized text
  """Overview
  --
  Removes punctuation from tokenized text

  Parameters
  --
  tokens : pandas DataFrame containing text as tokenized by the function "tokenize_korean"
  keep_periods : if true, periods aren't removed
  keep_commas : if true, commas aren't removed

  Returns
  --
  void
      deletes punctuation inplace on tokens
  """

  unrecognized_punc = {"‘","・","“"} #some puncutuation is not marked as punctuation
  mask = (tokens["pos"] == 'Punctuation')

  #used to keep periods and commas
  if keep_periods:
    mask = mask & (tokens["normalized"] != '.')
  if keep_commas:
    mask = mask & (tokens["normalized"] != ',')

  #removes unrecognized punc
  mask = mask | (tokens["normalized"].isin(unrecognized_punc))

  tokens.drop(tokens[mask].index, inplace = True)#drop is performed in place, not returned

# %%
#preps okt output for csv
def formatter_korean(surf, norm, stem, pos):
  """Overview
  --
  function to solve problem of potentially missaligned normalized and non-normalized tokens due to minor differnece in how tokens are split

  Parameters
  --
  surf : list of surface tokens as returned by morphs, must NOT be normalized or stemmed
  norm : list of normalized tokens as returned by pos, MUST be normalized but NOT stemmed
  stem : list of surface tokens as returned by morphs, MUST be normalized and stemmed
  pos : list of surface tokens as returned by py, MUST be normalized but NOT stemmed

  Returns
  --
  list(list)
      input lists aligned and zipped in the format for creating a pandas DataFrame
  """

  #find sections of overlapping surface and notmalized tokens
  #assumes most text does match between surface and stem
  diffs = difflib.SequenceMatcher(isjunk=None, a=surf, b=norm, autojunk=False)
  matches = diffs.get_matching_blocks()
  matches.insert(0,difflib.Match(0,0,0)) #dummy match added to find differences at front of list

  #used for tracking position in lists
  a_inserts = 0
  b_inserts = 0

  #find gaps between matching blocks
  for i in range(len(matches) - 1):
    front = matches[i]
    back = matches[i+1]

    #position tracking
    front_a = front.a + front.size + a_inserts
    back_a = back.a + a_inserts
    front_b = front.b + front.size + b_inserts
    back_b = back.b + b_inserts

    a_size = back_a - front_a
    b_size = back_b - front_b

    #if surface with no norm, insert norm as na (*)
    if b_size == 0:
      for i in range(a_size):
        norm.insert(front_b, "*")
        stem.insert(front_b, "*")
        pos.insert(front_b, "*")
      b_inserts += a_size
      continue

    #if norm with no surface, insert surface as na (*)
    if a_size == 0:
      concat_surf = "*"

    #if norm and surface, copy whole surface for each noram (*)
    else:
      concat_surf = "".join(surf[front_a:back_a])

    #remove old surface tags
    del surf[front_a:back_a]

    #insert to align with norm
    for i in range(b_size):
      surf.insert(front_a, concat_surf)
    a_inserts += a_size - b_size

    #return in correct format for pandas dataframe
    return zip(surf, norm, stem, pos)

# %% [markdown]
# ## Korean Tokenization Functions

# %%
def tokenize_korean(text, tokenizer): #tokenizer should be passed as argument so we only need to initiallize it once for all doucments
    """Overview
    --
    Tokenizes one text file

    Parameters
    --
    text : raw text, should be cleaned for best result
    tokenizer : tokenizer used for tokenization (in this case OKT)

    Returns
    --
    pd.Dataframe
        returns DataFrame object with tokenized text
    """

    norm,pos = map(list,zip(*(tokenizer.pos(text, norm=True))))
    surf = tokenizer.morphs(text)
    stem = tokenizer.morphs(text, norm=True, stem=True)

    #arranging data, not super elegant but fast enough
    data = formatter_korean(surf, norm, stem, pos)

    #put data into dataframe and return
    return pd.DataFrame(data, columns=['surface', 'normalized', 'dictionary' , 'pos'])

def mass_tokenize_korean(hash_list : list, in_folder : str, out_folder : str, stopwords : set = {}, readability : bool = True):
  """Overview
  --
  Tokenizes all files listed in hash list and corresponding text file

  Parameters
  --
  hash_list : list of hashes to tokenize
  in_folder : folder to look for txt files using hash as name
  out_folder : folder to write tokenized text csv files into
  stopwords : set of stopword to remove from all texts
  readability : if true, also writes csv with each files readability score as calculated by "korean_readability_index"

  Returns
  --
  void
      writes CSV files to out_folder
  """

  #ensures out_folder exists
  if not os.path.exists(out_folder):
      os.makedirs(out_folder)

  #initialize tokenizer only once
  okt = Okt()

  if readability:
    r_scores = [] #list for storing readability scores

  #iterate over every file in has list
  for hash in tqdm(hash_list):

    #open and clean text
    with open(f"{in_folder}/{hash}.txt", "r", encoding='utf-8') as f:
      text = f.read()
      text = clean_korean_text(text)

      #hangul check
      if is_hangul(text):
        tokens = tokenize_korean(text, okt) #tokenization
        remove_punc_korean(tokens) #first rount of stopwording, remove superflous puncuation

        #caluclate readabilty
        if readability:
          readability_score = korean_readability_index(tokens)

          #if caluclating readabilty fails and return as -1, print hash
          if readability_score == -1:
            print(hash)

          r_scores.append(readability_score)

        #first rount of stopwording, remove actual stopwords
        remove_stop_word_korean(tokens, stopwords = stopwords)

        # write to ./korean_preprocess
        tokens.to_csv(f"{out_folder}/{hash}.csv", index=False)

  #write readability with coresponding hash
  if readability:
    data = zip(hash_list,r_scores)
    r_scores_df = pd.DataFrame(data, columns = ["hash","readability"])
    r_scores_df.to_csv(f"{out_folder}/readability.csv", index=False)

# %% [markdown]
# ## Chinese Helper Function

# %%
def is_chinese(value):
    return hanzidentifier.has_chinese(value)

def chinese_clean_text_func(text):
    # Normalize newline characters
    text = re.sub('[\n\r]+', '\n', text)

    # Replace Chinese and English commas with ideographic comma '、'
    text = re.sub('[，,]', '、', text)

    # Remove special characters and punctuation
    text = re.sub(r'[^\w\s、]', '', text)

    # Normalize whitespace
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# %% [markdown]
# # Run Functions

# %% [markdown]
# ## Japanese

# %%
pr_j = cProfile.Profile()
pr_j.enable()

#get stopwords from stopwords-ko.txt
with open("stopwords/stopwords-ja.txt", "r") as f:
    stopwords = set(f.read().split("\n"))
print(len(stopwords))

mass_tokenize_japanese(ja_policy_list,"policies","corpus/japanese_preprocessed", stopwords = stopwords)

pr_j.disable()
pr_j.dump_stats('misc/stats_ja')
# Out:
# 134
#   0%|          | 0/1297 [00:00<?, ?it/s]
# b5e896e584195d83b30bc22323eb6fd352241a04e2f823185c6fef885f5a81b1
# d8cdc7cd6bceb9039f50d1d3a73f2926dbe2c52d22c45fe1b484a2197e3687c3
# fed50609e7a07e0fa9b37cd20a4152a0f030004291ac19e652f043760ce31f0c
# 46547d47482af14ac299d4a690fc58fb3b79cf942d1468e060d0a0be091599ee
# 8e9984b6e5da21c0f6801d1ee659bd378a8710bad7d0e79e1f721b0c9d45a496
# 179c99a8d1102197437d5766ffd26acae311ff27f78fca46723717a983707f2b
# f8b45b00b2437931453cbbae2c94bb20cb267336746035d301b4d8814151cb86
# b7a7f33e28302393f1586d02f0921840be7f662a1d1f899979e15838a0cfd265
# f27c7137d5041d704dc0c45c077a6f1adc4d13b1a48e07fac89686cd45bba84c
# 7798d2dd931b80ed5d4b661e5336e69e90f0d0b8f59bdf2b14dab26e0cfe7c53
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-17-250e285a690b> in <cell line: 9>()
#       7 print(len(stopwords))
#       8
# ----> 9 mass_tokenize_japanese(ja_policy_list,"policies","corpus/japanese_preprocessed", stopwords = stopwords)
#      10
#      11 pr_j.disable()
#
# <ipython-input-16-1de10c32db16> in mass_tokenize_japanese(hash_list, in_folder, out_folder, stopwords, readability)
#     120
#     121         # write to ./korean_preprocess
# --> 122         tokens.to_csv(f"{out_folder}/{hash}.csv", index=False)
#     123
#     124   #write readability with coresponding hash
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3770         )
#    3771
# -> 3772         return DataFrameRenderer(formatter).to_csv(
#    3773             path_or_buf,
#    3774             lineterminator=lineterminator,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1184             formatter=self.fmt,
#    1185         )
# -> 1186         csv_formatter.save()
#    1187
#    1188         if created_buffer:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in save(self)
#     257             )
#     258
# --> 259             self._save()
#     260
#     261     def _save(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save(self)
#     262         if self._need_to_save_header:
#     263             self._save_header()
# --> 264         self._save_body()
#     265
#     266     def _save_header(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_body(self)
#     300             if start_i >= end_i:
#     301                 break
# --> 302             self._save_chunk(start_i, end_i)
#     303
#     304     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     311
#     312         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 313         libwriters.write_csv_rows(
#     314             data,
#     315             ix,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# Error: need to escape, but no escapechar set

# %% [markdown]
# ## Korean

# %%
pr_k = cProfile.Profile()
pr_k.enable()

#get stopwords from stopwords-ko.txt
with open("stopwords/stopwords-ko.txt", "r") as f:
    stopwords = set(f.read().split("\n"))
print(len(stopwords))

mass_tokenize_korean(ko_policy_list,"policies","corpus/korean_preprocessed", stopwords = stopwords)

pr_k.disable()
pr_k.dump_stats('misc/stats_ko')
# Out:
# 595
#   0%|          | 0/916 [00:00<?, ?it/s]
# b20b783a3177517a157bf29c5d89fd8a47a1416580b76ce5f252c4de615008cf
# b20b783a3177517a157bf29c5d89fd8a47a1416580b76ce5f252c4de615008cf
# 4420efc565f17d826611b123eb45d04954e8a23fd83fd52d1f2bc51a272f27e4
# 4420efc565f17d826611b123eb45d04954e8a23fd83fd52d1f2bc51a272f27e4
# 5597b3218ddc51e0db6308218d9a5c757cc8e2ea8e212b69cb98ed82a25cb198
# 5597b3218ddc51e0db6308218d9a5c757cc8e2ea8e212b69cb98ed82a25cb198
# 44611a969a079b225d1b408e6a9671b9fe58bbaae1d05dc3e94941ae16627cc4
# 44611a969a079b225d1b408e6a9671b9fe58bbaae1d05dc3e94941ae16627cc4
# 015df2517c29fbda70f1ba7b9d8dcf8d6cd311b40c6c31008069790ba18feeea
# 015df2517c29fbda70f1ba7b9d8dcf8d6cd311b40c6c31008069790ba18feeea
# 8379c9822cad1e20fd6101614c18c1d6391592cca08567222109e011d6b022e9
# 8379c9822cad1e20fd6101614c18c1d6391592cca08567222109e011d6b022e9
# b0761540fd23bab5f5914a8fe89377bccaae2d762a85fb568d00d4c26bc18896
# b0761540fd23bab5f5914a8fe89377bccaae2d762a85fb568d00d4c26bc18896
# cbbe7a32ef09a2723175d6c800bb8c54dce7b750a448ec2f401d5110cb0fa213
# cbbe7a32ef09a2723175d6c800bb8c54dce7b750a448ec2f401d5110cb0fa213
# f8f723e8a4bf11b768b39745d74ec9c09e6dfdd644d7a93fc3221a4d82f6f185
# f8f723e8a4bf11b768b39745d74ec9c09e6dfdd644d7a93fc3221a4d82f6f185
# Thu Jul 11 19:01:29 2024    misc/stats
#
#          329433053 function calls (329320093 primitive calls) in 1620.262 seconds
#
#    Ordered by: internal time
#    List reduced from 900 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2094 1308.151    0.625 1353.746    0.646 _okt.py:58(pos)
#       844  183.237    0.217  221.746    0.263 difflib.py:305(find_longest_match)
# 291700215   38.516    0.000   38.516    0.000 {method 'get' of 'dict' objects}
#   7532815   30.189    0.000   31.535    0.000 _jarray.py:176(__next__)
#      2094   10.478    0.005   45.542    0.022 _okt.py:78(<listcomp>)
#      1617    8.841    0.005    8.861    0.005 {built-in method io.open}
#   7530721    3.529    0.000    3.529    0.000 {method 'rsplit' of 'str' objects}
#       705    2.510    0.004    2.510    0.004 {pandas._libs.writers.write_csv_rows}
#       698    2.018    0.003    2.994    0.004 difflib.py:266(__chain_b)
#       698    1.919    0.003 1584.794    2.270 <ipython-input-49-103f401d9c02>:42(tokenize_korean)
# 10022301/9957414    1.740    0.000    1.791    0.000 {built-in method builtins.len}
#       699    1.649    0.002    1.649    0.002 {method 'close' of '_io.TextIOWrapper' objects}
#      3472    1.599    0.000    1.599    0.000 {pandas._libs.ops.scalar_compare}
#       918    1.539    0.002    1.635    0.002 {method 'read' of '_io.TextIOWrapper' objects}
#      2748    1.421    0.001    1.421    0.001 {method 'sub' of 're.Pattern' objects}
#      1396    1.391    0.001    1.391    0.001 _okt.py:89(<listcomp>)
#      5574    1.390    0.000    2.966    0.001 frame.py:641(__init__)
#      1404    0.930    0.001    0.930    0.001 {built-in method pandas._libs.missing.isnaobj}
#      4170    0.795    0.000    0.795    0.000 {pandas._libs.algos.take_2d_axis1_object_object}
#   2222138    0.741    0.000    1.011    0.000 <ipython-input-41-5a664ebecad5>:13(<genexpr>)

# %%
#print stats

p = pstats.Stats('misc/stats_ja')
p.strip_dirs().sort_stats(SortKey.TIME).print_stats()

#files without periods/failed kri score:
"""

"""
# Out:
# Mon Jul 15 15:53:20 2024    misc/stats_ja
#
#          153837 function calls (150296 primitive calls) in 7.775 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      5188    2.632    0.001    2.632    0.001 {method 'sub' of 're.Pattern' objects}
#      1299    2.233    0.002    2.243    0.002 {built-in method io.open}
#      1298    1.815    0.001    1.888    0.001 {method 'read' of '_io.TextIOWrapper' objects}
#      1297    0.223    0.000    0.223    0.000 {method 'search' of '_regex.Pattern' objects}
#      1298    0.179    0.000    0.179    0.000 {method '__exit__' of '_io._IOBase' objects}
#         1    0.155    0.155    7.738    7.738 <ipython-input-29-dcf61e3884ff>:62(mass_tokenize_japanese)
#       223    0.094    0.000    0.094    0.000 socket.py:545(send)
#      1298    0.062    0.000    0.062    0.000 {built-in method _codecs.utf_8_decode}
#      1297    0.033    0.000    0.081    0.000 regex.py:449(_compile)
#         1    0.028    0.028    7.766    7.766 <ipython-input-30-250e285a690b>:1(<cell line: 9>)
#  2004/431    0.017    0.000    0.027    0.000 jsonutil.py:73(json_clean)
#      5256    0.016    0.000    0.021    0.000 re.py:288(_compile)
#      5188    0.015    0.000    2.667    0.001 re.py:202(sub)
# 27385/27376    0.014    0.000    0.019    0.000 {built-in method builtins.isinstance}
#      2594    0.014    0.000    0.029    0.000 enum.py:986(__and__)
#      1297    0.013    0.000    2.681    0.002 <ipython-input-25-a2773fb9cb4d>:4(clean_japanese_text)
#       864    0.012    0.000    0.018    0.000 encoder.py:204(iterencode)
#      1298    0.010    0.000    0.072    0.000 codecs.py:319(decode)
#      1297    0.010    0.000    0.011    0.000 regex.py:471(complain_unused_args)
#      1298    0.008    0.000    0.245    0.000 std.py:1160(__iter__)
#      1297    0.008    0.000    0.319    0.000 <ipython-input-25-a2773fb9cb4d>:1(is_kana)
#      1297    0.007    0.000    0.312    0.000 regex.py:263(search)
#      1298    0.007    0.000    0.010    0.000 codecs.py:309(__init__)
#      5188    0.007    0.000    0.013    0.000 enum.py:359(__call__)
# 8883/8147    0.007    0.000    0.023    0.000 traitlets.py:689(__get__)
# 8200/7676    0.006    0.000    0.016    0.000 traitlets.py:651(get)
#       233    0.006    0.000    0.006    0.000 {method 'acquire' of '_thread.lock' objects}
#      5188    0.006    0.000    0.006    0.000 enum.py:678(__new__)
#       216    0.006    0.000    0.156    0.001 session.py:662(send)
#        66    0.006    0.000    0.231    0.003 std.py:1198(update)
#      1298    0.005    0.000    0.006    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#       432    0.004    0.000    0.004    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#        69    0.004    0.000    0.006    0.000 std.py:464(format_meter)
#       218    0.003    0.000    0.208    0.001 widget.py:676(notify_change)
#      5292    0.003    0.000    0.003    0.000 {built-in method builtins.hasattr}
#       215    0.003    0.000    0.189    0.001 comm.py:61(_publish_msg)
#       864    0.003    0.000    0.026    0.000 __init__.py:183(dumps)
#      4014    0.003    0.000    0.003    0.000 {built-in method _abc._abc_instancecheck}
#        68    0.003    0.000    0.228    0.003 notebook.py:139(display)
#   215/208    0.003    0.000    0.015    0.000 widget.py:557(get_state)
#      1298    0.003    0.000    0.247    0.000 notebook.py:247(__iter__)
#       864    0.003    0.000    0.022    0.000 encoder.py:182(encode)
#       864    0.003    0.000    0.030    0.000 jsonapi.py:19(dumps)
#         1    0.003    0.003    0.003    0.003 {method 'close' of '_io.TextIOWrapper' objects}
#      3036    0.003    0.000    0.003    0.000 {method 'get' of 'dict' objects}
#       216    0.003    0.000    0.010    0.000 session.py:569(msg)
#       216    0.003    0.000    0.036    0.000 session.py:603(serialize)
#       223    0.002    0.000    0.100    0.000 iostream.py:195(schedule)
#      1298    0.002    0.000    0.002    0.000 codecs.py:260(__init__)
#       204    0.002    0.000    0.196    0.001 widget.py:538(send_state)
#   373/362    0.002    0.000    0.003    0.000 traitlets.py:1515(_notify_observers)
#       401    0.002    0.000    0.002    0.000 std.py:231(__call__)
#      4014    0.002    0.000    0.005    0.000 abc.py:117(__instancecheck__)
#       669    0.002    0.000    0.003    0.000 traitlets.py:1913(trait_metadata)
#   278/267    0.002    0.000    0.214    0.001 traitlets.py:702(set)
#       864    0.002    0.000    0.031    0.000 session.py:82(<lambda>)
#       237    0.001    0.000    0.002    0.000 traitlets.py:1882(traits)
#      1297    0.001    0.000    0.001    0.000 regex.py:476(<setcomp>)
#       864    0.001    0.000    0.001    0.000 encoder.py:104(__init__)
#       216    0.001    0.000    0.001    0.000 {method 'replace' of 'datetime.datetime' objects}
#       204    0.001    0.000    0.185    0.001 comm.py:120(send)
#      1298    0.001    0.000    0.001    0.000 {method 'strip' of 'str' objects}
#       432    0.001    0.000    0.007    0.000 jsonutil.py:84(date_default)
#   406/400    0.001    0.000    0.005    0.000 traitlets.py:731(_validate)
#   220/215    0.001    0.000    0.002    0.000 widget.py:93(_separate_buffers)
# 1553/1101    0.001    0.000    0.011    0.000 {built-in method builtins.getattr}
#       136    0.001    0.000    0.001    0.000 std.py:400(format_interval)
# 4068/4045    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#        69    0.001    0.000    0.003    0.000 std.py:1446(format_dict)
#       263    0.001    0.000    0.002    0.000 traitlets.py:740(_cross_validate)
#   250/239    0.001    0.000    0.209    0.001 traitlets.py:1500(_notify_trait)
#       225    0.001    0.000    0.001    0.000 {method 'append' of 'collections.deque' objects}
#       204    0.001    0.000    0.187    0.001 widget.py:814(_send)
#      1322    0.001    0.000    0.001    0.000 {method 'replace' of 'str' objects}
#       218    0.001    0.000    0.001    0.000 {built-in method posix.getpid}
#       204    0.001    0.000    0.003    0.000 widget.py:724(_should_send_property)
#         3    0.001    0.000    0.001    0.000 {built-in method posix.stat}
#       225    0.001    0.000    0.002    0.000 threading.py:1169(is_alive)
#        66    0.001    0.000    0.223    0.003 std.py:1325(refresh)
#       216    0.001    0.000    0.002    0.000 session.py:513(msg_id)
#       216    0.001    0.000    0.101    0.000 iostream.py:260(send_multipart)
#        69    0.001    0.000    0.002    0.000 notebook.py:192(colour)
#       216    0.001    0.000    0.006    0.000 session.py:566(msg_header)
#       287    0.001    0.000    0.001    0.000 {method 'format' of 'str' objects}
#   264/253    0.001    0.000    0.215    0.001 traitlets.py:720(__set__)
#        69    0.001    0.000    0.001    0.000 std.py:102(acquire)
#       216    0.001    0.000    0.002    0.000 session.py:149(utcnow)
#       216    0.001    0.000    0.001    0.000 session.py:744(<listcomp>)
#   251/240    0.001    0.000    0.003    0.000 traitlets.py:1511(notify_change)
#        66    0.001    0.000    0.232    0.004 notebook.py:260(update)
#       216    0.001    0.000    0.100    0.000 iostream.py:207(send_multipart)
#       223    0.001    0.000    0.001    0.000 iostream.py:91(_event_pipe)
#       878    0.001    0.000    0.001    0.000 {method 'encode' of 'str' objects}
#       216    0.000    0.000    0.003    0.000 session.py:218(msg_header)
#        69    0.000    0.000    0.001    0.000 std.py:106(release)
#       216    0.000    0.000    0.000    0.000 {built-in method utcnow}
#       225    0.000    0.000    0.001    0.000 threading.py:1102(_wait_for_tstate_lock)
#       215    0.000    0.000    0.002    0.000 widget.py:138(_remove_buffers)
#       480    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       136    0.000    0.000    0.001    0.000 __init__.py:12(escape)
#       216    0.000    0.000    0.000    0.000 session.py:224(extract_header)
#       216    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        67    0.000    0.000    0.000    0.000 {built-in method now}
#       432    0.000    0.000    0.000    0.000 jsonutil.py:31(_ensure_tzinfo)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#      1619    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#    122/46    0.000    0.000    0.010    0.000 traitlets.py:1856(trait_defaults)
#       114    0.000    0.000    0.003    0.000 traitlets.py:1226(__call__)
#        68    0.000    0.000    0.000    0.000 {method 'split' of 're.Pattern' objects}
#       216    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        68    0.000    0.000    0.001    0.000 widget_float.py:33(_validate_value)
#       216    0.000    0.000    0.001    0.000 session.py:588(sign)
#        68    0.000    0.000    0.001    0.000 re.py:222(split)
#        73    0.000    0.000    0.000    0.000 traitlets.py:2432(validate)
#       381    0.000    0.000    0.000    0.000 {built-in method time.time}
#       868    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        69    0.000    0.000    0.000    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       122    0.000    0.000    0.000    0.000 traitlets.py:1844(_get_trait_default_generator)
#       352    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       608    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        26    0.000    0.000    0.001    0.000 traitlets.py:1325(__init__)
#       220    0.000    0.000    0.000    0.000 jsonutil.py:131(<listcomp>)
#       731    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       169    0.000    0.000    0.000    0.000 traitlets.py:2523(validate)
#        73    0.000    0.000    0.000    0.000 traitlets.py:2336(_validate_bounds)
#       273    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#       226    0.000    0.000    0.000    0.000 threading.py:553(is_set)
#       457    0.000    0.000    0.000    0.000 widget.py:779(_trait_to_json)
#        73    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#        26    0.000    0.000    0.000    0.000 traitlets.py:1283(setup_instance)
#      11/4    0.000    0.000    0.013    0.003 widget.py:490(open)
#       5/4    0.000    0.000    0.001    0.000 series.py:368(__init__)
#        11    0.000    0.000    0.000    0.000 uuid.py:138(__init__)
#        69    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#        26    0.000    0.000    0.001    0.000 traitlets.py:1311(setup_instance)
#       492    0.000    0.000    0.000    0.000 traitlets.py:263(__init__)
#        11    0.000    0.000    0.000    0.000 {built-in method posix.urandom}
#        11    0.000    0.000    0.002    0.000 configurable.py:51(__init__)
#        26    0.000    0.000    0.001    0.000 traitlets.py:1268(__new__)
#       492    0.000    0.000    0.000    0.000 traitlets.py:266(__call__)
#        69    0.000    0.000    0.000    0.000 utils.py:108(__init__)
#        69    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#         6    0.000    0.000    0.001    0.000 construction.py:494(sanitize_array)
#         4    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_convert_objects}
#       2/1    0.000    0.000    0.008    0.008 display.py:131(display)
#         1    0.000    0.000    0.003    0.003 construction.py:411(dict_to_mgr)
#        11    0.000    0.000    0.001    0.000 configurable.py:157(_load_config)
#        11    0.000    0.000    0.006    0.001 comm.py:80(open)
#        22    0.000    0.000    0.000    0.000 configurable.py:126(<listcomp>)
#         4    0.000    0.000    7.774    1.944 interactiveshell.py:3512(run_code)
#     78/30    0.000    0.000    0.009    0.000 traitlets.py:613(default)
#        11    0.000    0.000    0.008    0.001 comm.py:50(__init__)
#        73    0.000    0.000    0.000    0.000 abc.py:121(__subclasscheck__)
#        26    0.000    0.000    0.000    0.000 traitlets.py:2167(make_dynamic_default)
#         1    0.000    0.000    0.024    0.024 notebook.py:202(__init__)
#        83    0.000    0.000    0.000    0.000 generic.py:37(_check)
#       150    0.000    0.000    0.000    0.000 traitlets.py:1796(has_trait)
#         2    0.000    0.000    0.001    0.000 base.py:469(__new__)
#       239    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        85    0.000    0.000    0.000    0.000 traitlets.py:2142(validate)
#      11/4    0.000    0.000    0.013    0.003 widget.py:474(__init__)
#        83    0.000    0.000    0.000    0.000 generic.py:42(_instancecheck)
#         1    0.000    0.000    0.004    0.004 frame.py:641(__init__)
#        69    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 format.py:564(__init__)
#        24    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.isnaobj}
#        15    0.000    0.000    0.000    0.000 contextlib.py:102(__init__)
#       497    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#        21    0.000    0.000    0.000    0.000 traitlets.py:2848(validate)
#         1    0.000    0.000    0.000    0.000 std.py:952(__init__)
#        33    0.000    0.000    0.000    0.000 traitlets.py:1624(observe)
#         6    0.000    0.000    0.000    0.000 generic.py:265(__init__)
#        89    0.000    0.000    0.000    0.000 traitlets.py:2158(instance_init)
#         2    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        22    0.000    0.000    0.000    0.000 traitlets.py:1435(hold_trait_notifications)
#        11    0.000    0.000    0.000    0.000 uuid.py:718(uuid4)
#        11    0.000    0.000    0.000    0.000 widget.py:505(_comm_changed)
#        10    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#        11    0.000    0.000    0.000    0.000 configurable.py:132(_find_my_config)
#        89    0.000    0.000    0.000    0.000 traitlets.py:2163(_resolve_classes)
#        33    0.000    0.000    0.000    0.000 traitlets.py:1562(_add_notifiers)
#         1    0.000    0.000    0.007    0.007 common.py:648(get_handle)
#         4    0.000    0.000    0.000    0.000 interactiveshell.py:3337(_update_code_co_name)
#        44    0.000    0.000    0.000    0.000 traitlets.py:237(parse_notifier_name)
#         5    0.000    0.000    0.000    0.000 pathlib.py:56(parse_parts)
#         4    0.000    0.000    0.000    0.000 numeric.py:274(full)
#         1    0.000    0.000    0.007    0.007 <ipython-input-30-250e285a690b>:1(<cell line: 5>)
#         9    0.000    0.000    0.001    0.000 base.py:7072(ensure_index)
#        22    0.000    0.000    0.000    0.000 loader.py:240(__init__)
#         2    0.000    0.000    0.000    0.000 series.py:4632(_reduce)
#         1    0.000    0.000    0.010    0.010 generic.py:3589(to_csv)
#      11/9    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#        33    0.000    0.000    0.000    0.000 loader.py:218(_is_section_key)
#         1    0.000    0.000    0.014    0.014 notebook.py:94(status_printer)
#        11    0.000    0.000    0.001    0.000 manager.py:45(register_comm)
#        33    0.000    0.000    0.000    0.000 loader.py:297(__contains__)
#         4    0.000    0.000    0.000    0.000 codeop.py:117(__call__)
#        70    0.000    0.000    0.000    0.000 {built-in method math.isnan}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#        14    0.000    0.000    0.000    0.000 managers.py:2000(dtype)
#         3    0.000    0.000    0.000    0.000 generic.py:5931(__finalize__)
#         8    0.000    0.000    0.000    0.000 {built-in method posix.lstat}
#         3    0.000    0.000    0.000    0.000 base.py:640(_simple_new)
#        11    0.000    0.000    0.000    0.000 comm.py:26(_default_comm_id)
#        22    0.000    0.000    0.000    0.000 traitlets.py:1244(instance_init)
#         3    0.000    0.000    0.000    0.000 blocks.py:2385(new_block)
#        33    0.000    0.000    0.000    0.000 loader.py:310(_has_section)
#         3    0.000    0.000    0.000    0.000 cast.py:1573(construct_1d_object_array_from_listlike)
#         7    0.000    0.000    0.000    0.000 common.py:1656(pandas_dtype)
#         1    0.000    0.000    0.000    0.000 posixpath.py:401(_joinrealpath)
#         1    0.000    0.000    0.000    0.000 managers.py:1958(getitem_mgr)
#        11    0.000    0.000    0.000    0.000 common.py:1244(is_bool_dtype)
#         1    0.000    0.000    0.000    0.000 blocks.py:1011(setitem)
#        22    0.000    0.000    0.000    0.000 configurable.py:123(section_names)
#        12    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#        34    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        11    0.000    0.000    0.001    0.000 widget.py:461(_default_keys)
#        15    0.000    0.000    0.000    0.000 traitlets.py:2996(validate_elements)
#         1    0.000    0.000    0.007    0.007 zmqshell.py:97(publish)
#        18    0.000    0.000    0.000    0.000 traitlets.py:1686(_register_validator)
#         6    0.000    0.000    0.000    0.000 _ufunc_config.py:33(seterr)
#        15    0.000    0.000    0.000    0.000 contextlib.py:279(helper)
#         7    0.000    0.000    0.000    0.000 config.py:116(_get_single_key)
#         5    0.000    0.000    0.000    0.000 pathlib.py:569(_parse_args)
#         8    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#         2    0.000    0.000    0.000    0.000 utils.py:421(check_array_indexer)
#         2    0.000    0.000    0.006    0.003 iostream.py:335(flush)
#         2    0.000    0.000    0.000    0.000 os.py:675(__getitem__)
#         6    0.000    0.000    0.000    0.000 generic.py:5991(__setattr__)
#        12    0.000    0.000    0.000    0.000 common.py:1494(_is_dtype_type)
#        32    0.000    0.000    0.000    0.000 widget.py:515(model_id)
#        15    0.000    0.000    0.000    0.000 contextlib.py:139(__exit__)
#         1    0.000    0.000    0.000    0.000 managers.py:2191(_form_blocks)
#        70    0.000    0.000    0.000    0.000 {built-in method math.isinf}
#         1    0.000    0.000    0.010    0.010 csvs.py:235(save)
#         2    0.000    0.000    0.000    0.000 missing.py:189(_isna)
#         9    0.000    0.000    0.000    0.000 managers.py:2011(internal_values)
#        15    0.000    0.000    0.000    0.000 contextlib.py:130(__enter__)
#        11    0.000    0.000    0.000    0.000 comm.py:19(_default_kernel)
#         1    0.000    0.000    0.000    0.000 utils.py:333(_screen_shape_linux)
#        10    0.000    0.000    0.000    0.000 generic.py:5975(__getattr__)
#         2    0.000    0.000    0.000    0.000 managers.py:306(apply)
#         7    0.000    0.000    0.009    0.001 trait_types.py:167(make_dynamic_default)
#        14    0.000    0.000    0.000    0.000 traitlets.py:1732(set_trait)
#         4    0.000    0.000    0.000    0.000 common.py:95(is_bool_indexer)
#        13    0.000    0.000    0.000    0.000 configurable.py:522(instance)
#        11    0.000    0.000    0.000    0.000 uuid.py:333(hex)
#         2    0.000    0.000    0.000    0.000 nanops.py:264(_get_values)
#      11/8    0.000    0.000    0.000    0.000 widget.py:51(_widget_to_json)
#        11    0.000    0.000    0.000    0.000 widget.py:463(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.invert}
#        33    0.000    0.000    0.000    0.000 traitlets.py:1233(__get__)
#         1    0.000    0.000    0.008    0.008 formatters.py:903(__call__)
#         4    0.000    0.000    0.000    0.000 cast.py:1171(maybe_infer_to_datetimelike)
#         2    0.000    0.000    0.000    0.000 threading.py:236(__init__)
#        39    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x5bbc396549a0}
#         1    0.000    0.000    0.000    0.000 series.py:992(__getitem__)
#         2    0.000    0.000    0.000    0.000 cast.py:123(maybe_convert_platform)
#         2    0.000    0.000    0.001    0.001 iostream.py:384(write)
#        50    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 pathlib.py:589(_from_parts)
#         8    0.000    0.000    0.000    0.000 posixpath.py:71(join)
#         1    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#         1    0.000    0.000    0.000    0.000 parse.py:444(urlsplit)
#         2    0.000    0.000    0.006    0.003 threading.py:288(wait)
#         2    0.000    0.000    0.000    0.000 pathlib.py:865(parent)
#         1    0.000    0.000    0.000    0.000 common.py:285(_get_filepath_or_buffer)
#        21    0.000    0.000    0.000    0.000 traitlets.py:2860(validate_elements)
#         1    0.000    0.000    0.000    0.000 csvs.py:50(__init__)
#         1    0.000    0.000    0.000    0.000 posixpath.py:392(realpath)
#         7    0.000    0.000    0.000    0.000 config.py:134(_get_option)
#         1    0.000    0.000    0.000    0.000 std.py:663(__new__)
#         6    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#         7    0.000    0.000    0.000    0.000 config.py:596(_get_root)
#         8    0.000    0.000    0.000    0.000 series.py:671(name)
#        14    0.000    0.000    0.000    0.000 config.py:610(_get_deprecated_option)
#         1    0.000    0.000    0.000    0.000 base.py:1364(_format_native_types)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         4    0.000    0.000    0.000    0.000 traitlets.py:2689(validate)
#         1    0.000    0.000    0.000    0.000 indexing.py:2038(_setitem_single_block)
#         1    0.000    0.000    0.001    0.001 indexing.py:831(__setitem__)
#        18    0.000    0.000    0.000    0.000 traitlets.py:1252(instance_init)
#         1    0.000    0.000    0.010    0.010 format.py:1137(to_csv)
#         2    0.000    0.000    0.000    0.000 missing.py:307(_isna_string_dtype)
#         1    0.000    0.000    0.005    0.005 notebook.py:272(close)
#         4    0.000    0.000    0.000    0.000 blocks.py:2334(get_block_type)
#        11    0.000    0.000    0.000    0.000 comm.py:38(_default_topic)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#         9    0.000    0.000    0.000    0.000 series.py:621(name)
#         8    0.000    0.000    0.000    0.000 dis.py:453(findlinestarts)
#         1    0.000    0.000    0.000    0.000 csvs.py:222(encoded_labels)
#        20    0.000    0.000    0.000    0.000 {built-in method sys.intern}
#         4    0.000    0.000    0.000    0.000 hooks.py:103(__call__)
#         1    0.000    0.000    0.000    0.000 __init__.py:22(_get_absolute_dict_path)
#         2    0.000    0.000    0.000    0.000 common.py:1151(_is_binary_mode)
#        15    0.000    0.000    0.000    0.000 inference.py:328(is_hashable)
#        14    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.000    0.000 nanops.py:86(_f)
#         1    0.000    0.000    0.000    0.000 {method 'create' of 'sudachipy.dictionary.Dictionary' objects}
#         2    0.000    0.000    0.000    0.000 indexing.py:2476(check_bool_indexer)
#         1    0.000    0.000    0.000    0.000 __init__.py:28(_find_dict_path)
#         8    0.000    0.000    0.000    0.000 compilerop.py:166(extra_flags)
#         1    0.000    0.000    0.000    0.000 generic.py:10967(_logical_func)
#         1    0.000    0.000    0.000    0.000 formatters.py:397(lookup_by_type)
#         4    0.000    0.000    7.774    1.944 {built-in method builtins.exec}
#         1    0.000    0.000    0.007    0.007 widget.py:789(_ipython_display_)
#         1    0.000    0.000    0.000    0.000 util.py:73(find_spec)
#        11    0.000    0.000    0.000    0.000 traitlets.py:1654(unobserve)
#         1    0.000    0.000    0.000    0.000 std.py:1265(close)
#         2    0.000    0.000    0.000    0.000 cast.py:1512(construct_1d_arraylike_from_scalar)
#         5    0.000    0.000    0.000    0.000 common.py:653(is_integer_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:5159(__getitem__)
#         1    0.000    0.000    0.000    0.000 csvs.py:294(_save_body)
#         9    0.000    0.000    0.000    0.000 construction.py:396(extract_array)
#         7    0.000    0.000    0.000    0.000 trait_types.py:161(validate)
#         4    0.000    0.000    0.000    0.000 pathlib.py:621(__str__)
#         1    0.000    0.000    0.000    0.000 indexing.py:1689(_setitem_with_indexer)
#         3    0.000    0.000    0.000    0.000 common.py:1209(is_float_dtype)
#       4/1    0.000    0.000    0.000    0.000 widget.py:775(_handle_displayed)
#         7    0.000    0.000    0.000    0.000 config.py:260(__call__)
#         5    0.000    0.000    0.000    0.000 base.py:7167(maybe_extract_name)
#         1    0.000    0.000    0.000    0.000 putmask.py:132(setitem_datetimelike_compat)
#         1    0.000    0.000    0.000    0.000 parse.py:379(urlparse)
#         3    0.000    0.000    0.000    0.000 generic.py:723(_set_axis)
#        11    0.000    0.000    0.000    0.000 traitlets.py:1575(_remove_notifiers)
#         2    0.000    0.000    0.000    0.000 pathlib.py:957(__new__)
#        18    0.000    0.000    0.000    0.000 common.py:1459(get_dtype)
#         1    0.000    0.000    0.000    0.000 generic.py:1455(__invert__)
#         2    0.000    0.000    0.006    0.003 threading.py:589(wait)
#         1    0.000    0.000    0.000    0.000 series.py:521(_init_dict)
#         1    0.000    0.000    0.000    0.000 indexing.py:685(_get_setitem_indexer)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1022(_find_and_load)
#         8    0.000    0.000    0.000    0.000 common.py:1631(validate_all_hashable)
#         1    0.000    0.000    0.000    0.000 _asarray.py:27(require)
#         1    0.000    0.000    0.000    0.000 std.py:686(_decr_instances)
#        16    0.000    0.000    0.000    0.000 base.py:875(__len__)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         3    0.000    0.000    0.000    0.000 base.py:58(_validate_set_axis)
#         1    0.000    0.000    0.000    0.000 utils.py:125(__eq__)
#         1    0.000    0.000    0.000    0.000 common.py:534(infer_compression)
#         1    0.000    0.000    0.000    0.000 indexing.py:1364(_convert_to_indexer)
#         1    0.000    0.000    0.008    0.008 formatters.py:89(format)
#        11    0.000    0.000    0.000    0.000 traitlets.py:2604(validate)
#        10    0.000    0.000    0.000    0.000 formatters.py:550(_in_deferred_types)
#         3    0.000    0.000    0.000    0.000 traitlets.py:3345(validate)
#         1    0.000    0.000    0.006    0.006 zmqshell.py:80(_flush_streams)
#         6    0.000    0.000    0.000    0.000 flags.py:49(__init__)
#         1    0.000    0.000    0.000    0.000 nanops.py:609(nansum)
#         5    0.000    0.000    0.000    0.000 construction.py:644(_sanitize_ndim)
#         1    0.000    0.000    0.000    0.000 managers.py:2249(_stack_arrays)
#         8    0.000    0.000    0.000    0.000 common.py:1435(_is_dtype)
#         1    0.000    0.000    0.000    0.000 std.py:679(_get_free_pos)
#         1    0.000    0.000    0.001    0.001 pathlib.py:1300(is_dir)
#         1    0.000    0.000    0.000    0.000 generic.py:11240(_min_count_stat_function)
#         2    0.000    0.000    0.000    0.000 managers.py:1873(from_array)
#        11    0.000    0.000    0.000    0.000 __init__.py:33(using_copy_on_write)
#         1    0.000    0.000    0.001    0.001 common.py:589(check_parent_directory)
#         1    0.000    0.000    0.000    0.000 managers.py:2119(create_block_manager_from_column_arrays)
#        70    0.000    0.000    0.000    0.000 traitlets.py:512(instance_init)
#         7    0.000    0.000    0.000    0.000 config.py:578(_select_options)
#         1    0.000    0.000    0.000    0.000 _dtype.py:346(_name_get)
#         1    0.000    0.000    0.007    0.007 display.py:81(publish_display_data)
#        11    0.000    0.000    0.000    0.000 comm.py:137(on_msg)
#         2    0.000    0.000    0.000    0.000 inference.py:267(is_dict_like)
#        14    0.000    0.000    0.000    0.000 series.py:594(dtype)
#         3    0.000    0.000    0.000    0.000 blocks.py:2305(maybe_coerce_values)
#         9    0.000    0.000    0.000    0.000 series.py:718(_values)
#        22    0.000    0.000    0.000    0.000 loader.py:244(_ensure_subconfig)
#         1    0.000    0.000    0.000    0.000 warnings.py:458(__enter__)
#         1    0.000    0.000    0.000    0.000 {built-in method _csv.writer}
#         1    0.000    0.000    0.003    0.003 common.py:117(close)
#         1    0.000    0.000    0.000    0.000 construction.py:574(_homogenize)
#         3    0.000    0.000    0.000    0.000 blocks.py:2401(check_ndim)
#        11    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#        13    0.000    0.000    0.000    0.000 configurable.py:566(initialized)
#         5    0.000    0.000    0.000    0.000 managers.py:1847(__init__)
#         1    0.000    0.000    0.000    0.000 nanops.py:499(nanany)
#         1    0.000    0.000    0.000    0.000 missing.py:625(na_value_for_dtype)
#         1    0.000    0.000    0.000    0.000 functools.py:393(__get__)
#        34    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 csvs.py:140(has_mi_columns)
#        16    0.000    0.000    0.000    0.000 common.py:1650(<genexpr>)
#         1    0.000    0.000    0.000    0.000 utils.py:347(<listcomp>)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 utils.py:213(__init__)
#         6    0.000    0.000    0.000    0.000 common.py:1077(needs_i8_conversion)
#         1    0.000    0.000    0.000    0.000 posixpath.py:338(normpath)
#         3    0.000    0.000    0.000    0.000 posixpath.py:229(expanduser)
#         5    0.000    0.000    0.000    0.000 construction.py:458(ensure_wrapped_if_datetimelike)
#         5    0.000    0.000    0.000    0.000 pathlib.py:239(splitroot)
#         7    0.000    0.000    0.000    0.000 config.py:649(_warn_if_deprecated)
#         4    0.000    0.000    0.000    0.000 common.py:1335(is_extension_array_dtype)
#         2    0.000    0.000    0.000    0.000 missing.py:266(_isna_array)
#         1    0.000    0.000    0.000    0.000 csvs.py:144(_initialize_columns)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:100(acquire)
#         1    0.000    0.000    0.000    0.000 widget_box.py:67(_fire_children_displayed)
#         1    0.000    0.000    0.000    0.000 cast.py:891(infer_dtype_from_array)
#         5    0.000    0.000    0.000    0.000 construction.py:683(_sanitize_str_dtypes)
#         2    0.000    0.000    0.000    0.000 notebook.py:197(colour)
#         4    0.000    0.000    0.000    0.000 interactiveshell.py:3449(compare)
#        40    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 common.py:158(is_object_dtype)
#         1    0.000    0.000    0.000    0.000 csvs.py:266(_save_header)
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         2    0.000    0.000    0.000    0.000 threading.py:545(__init__)
#         3    0.000    0.000    0.000    0.000 _ufunc_config.py:430(__enter__)
#         4    0.000    0.000    0.000    0.000 {method 'replace' of 'code' objects}
#         4    0.000    0.000    0.000    0.000 ipstruct.py:125(__getattr__)
#         1    0.000    0.000    0.000    0.000 pathlib.py:1064(resolve)
#         3    0.000    0.000    0.000    0.000 common.py:169(_expand_user)
#         1    0.000    0.000    0.000    0.000 <ipython-input-30-250e285a690b>:1(<cell line: 11>)
#         1    0.000    0.000    0.008    0.008 formatters.py:220(catch_format_error)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:71(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method fromtimestamp}
#         2    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#        12    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#       4/1    0.000    0.000    0.000    0.000 widget.py:201(__call__)
#         2    0.000    0.000    0.000    0.000 common.py:229(stringify_path)
#         1    0.000    0.000    0.000    0.000 genericpath.py:16(exists)
#         1    0.000    0.000    0.000    0.000 utils.py:273(_is_ascii)
#         2    0.000    0.000    0.000    0.000 iostream.py:308(_is_master_process)
#         1    0.000    0.000    0.000    0.000 base.py:767(__iter__)
#         5    0.000    0.000    0.000    0.000 generic.py:509(_get_axis_number)
#         1    0.000    0.000    0.003    0.003 widget_box.py:62(__init__)
#         1    0.000    0.000    0.000    0.000 notebook.py:80(__repr__)
#         2    0.000    0.000    0.000    0.000 managers.py:1860(from_blocks)
#         3    0.000    0.000    0.000    0.000 {method 'add_index_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#         2    0.000    0.000    0.000    0.000 base.py:565(_ensure_array)
#         1    0.000    0.000    0.000    0.000 notebook.py:71(_json_)
#        11    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#        33    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 range.py:166(_simple_new)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:86(add)
#         3    0.000    0.000    0.000    0.000 std.py:110(__enter__)
#         2    0.000    0.000    0.001    0.000 pathlib.py:1092(stat)
#         1    0.000    0.000    0.000    0.000 construction.py:97(arrays_to_mgr)
#         2    0.000    0.000    0.000    0.000 csvs.py:200(_has_aliases)
#         3    0.000    0.000    0.000    0.000 generic.py:523(_get_axis)
#        11    0.000    0.000    0.000    0.000 traitlets.py:2481(validate)
#         1    0.000    0.000    0.000    0.000 common.py:141(is_url)
#         2    0.000    0.000    0.000    0.000 series.py:869(__array__)
#        21    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         1    0.000    0.000    0.000    0.000 managers.py:380(setitem)
#         1    0.000    0.000    0.000    0.000 indexing.py:718(_maybe_mask_setitem_value)
#         4    0.000    0.000    0.000    0.000 common.py:1389(is_ea_or_datetimelike_dtype)
#         1    0.000    0.000    0.000    0.000 csvs.py:208(write_cols)
#         1    0.000    0.000    0.000    0.000 _methods.py:55(_any)
#         4    0.000    0.000    0.000    0.000 nanops.py:89(<genexpr>)
#         1    0.000    0.000    0.000    0.000 csvs.py:261(_save)
#         3    0.000    0.000    0.000    0.000 _ufunc_config.py:435(__exit__)
#         1    0.000    0.000    0.000    0.000 blocks.py:198(_standardize_fill_value)
#         3    0.000    0.000    0.000    0.000 managers.py:223(set_axis)
#         1    0.000    0.000    0.000    0.000 generic.py:11010(any)
#         1    0.000    0.000    0.000    0.000 series.py:1095(_get_values)
#         1    0.000    0.000    0.000    0.000 csvs.py:168(_number_format)
#         2    0.000    0.000    0.000    0.000 iostream.py:321(_schedule_flush)
#         1    0.000    0.000    0.000    0.000 common.py:273(is_fsspec_url)
#         1    0.000    0.000    0.000    0.000 series.py:1327(_check_is_chained_assignment_possible)
#         2    0.000    0.000    0.000    0.000 blocks.py:2465(extend_blocks)
#         3    0.000    0.000    0.000    0.000 pathlib.py:608(_format_parsed_parts)
#         1    0.000    0.000    0.000    0.000 nanops.py:406(new_func)
#         1    0.000    0.000    0.000    0.000 blocks.py:323(apply)
#        11    0.000    0.000    0.000    0.000 widget.py:334(_call_widget_constructed)
#         1    0.000    0.000    0.000    0.000 {method 'writerow' of '_csv.writer' objects}
#         7    0.000    0.000    0.000    0.000 config.py:637(_translate_key)
#         2    0.000    0.000    0.000    0.000 indexing.py:2609(check_dict_or_set_indexers)
#         2    0.000    0.000    0.000    0.000 os.py:755(encode)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#         1    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 generic.py:7878(isna)
#         3    0.000    0.000    0.000    0.000 flags.py:85(allows_duplicate_labels)
#         4    0.000    0.000    0.000    0.000 interactiveshell.py:1302(user_global_ns)
#         2    0.000    0.000    0.000    0.000 parse.py:122(_coerce_args)
#         3    0.000    0.000    0.000    0.000 traitlets.py:3352(validate_elements)
#         1    0.000    0.000    0.001    0.001 <ipython-input-30-250e285a690b>:1(<cell line: 7>)
#         2    0.000    0.000    0.007    0.003 widget_string.py:29(__init__)
#         1    0.000    0.000    0.000    0.000 api.py:367(default_index)
#         2    0.000    0.000    0.000    0.000 managers.py:2175(_grouping_func)
#         7    0.000    0.000    0.000    0.000 common.py:142(classes)
#         1    0.000    0.000    0.000    0.000 series.py:1338(_maybe_update_cacher)
#         1    0.000    0.000    0.000    0.000 {built-in method fcntl.ioctl}
#         1    0.000    0.000    0.000    0.000 blocks.py:901(_slice)
#         2    0.000    0.000    0.000    0.000 std.py:1157(__hash__)
#         1    0.000    0.000    0.000    0.000 std.py:186(__format__)
#         1    0.000    0.000    0.000    0.000 typing.py:993(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 _validators.py:224(validate_bool_kwarg)
#         2    0.000    0.000    0.000    0.000 base.py:583(_dtype_to_subclass)
#        33    0.000    0.000    0.000    0.000 {function Config.__contains__ at 0x7d895779fd00}
#         2    0.000    0.000    0.000    0.000 pathlib.py:615(_make_child)
#         1    0.000    0.000    0.000    0.000 generic.py:11311(any)
#         1    0.000    0.000    0.000    0.000 generic.py:11272(sum)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:63(__iter__)
#         3    0.000    0.000    0.000    0.000 _ufunc_config.py:426(__init__)
#         2    0.000    0.000    0.000    0.000 generic.py:453(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 __init__.py:108(import_module)
#        17    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 typing.py:1737(cast)
#         4    0.000    0.000    0.000    0.000 base.py:809(_reset_identity)
#         1    0.000    0.000    0.000    0.000 formatters.py:374(lookup)
#         7    0.000    0.000    0.000    0.000 common.py:144(<lambda>)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:111(remove)
#         3    0.000    0.000    0.000    0.000 pathlib.py:631(__fspath__)
#        10    0.000    0.000    0.000    0.000 posixpath.py:41(_get_sep)
#         2    0.000    0.000    0.000    0.000 base.py:494(find)
#         1    0.000    0.000    0.000    0.000 format.py:479(get_adjustment)
#         1    0.000    0.000    0.000    0.000 dir2.py:54(get_real_method)
#         1    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#         2    0.000    0.000    0.000    0.000 posixpath.py:60(isabs)
#         1    0.000    0.000    0.000    0.000 common.py:296(maybe_iterable_to_list)
#         4    0.000    0.000    0.000    0.000 inference.py:189(is_array_like)
#         2    0.000    0.000    0.000    0.000 utils.py:187(disable_on_exception)
#         4    0.000    0.000    0.000    0.000 range.py:892(__len__)
#         1    0.000    0.000    0.000    0.000 generic.py:3800(_maybe_update_cacher)
#         2    0.000    0.000    0.000    0.000 threading.py:264(__enter__)
#         5    0.000    0.000    0.000    0.000 construction.py:703(_maybe_repeat)
#         1    0.000    0.000    0.000    0.000 _asarray.py:108(<setcomp>)
#         2    0.000    0.000    0.000    0.000 common.py:498(is_string_or_object_np_dtype)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:125(release)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         1    0.000    0.000    0.000    0.000 typing.py:1154(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 utils.py:266(_supports_unicode)
#         1    0.000    0.000    0.000    0.000 csvs.py:121(_get_index_label_from_obj)
#         1    0.000    0.000    0.000    0.000 format.py:683(_initialize_justify)
#         2    0.000    0.000    0.000    0.000 base.py:5314(equals)
#         1    0.000    0.000    0.000    0.000 managers.py:523(is_view)
#         3    0.000    0.000    0.000    0.000 common.py:571(require_length_match)
#         8    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         3    0.000    0.000    0.000    0.000 utils.py:152(wrapper_setattr)
#        18    0.000    0.000    0.000    0.000 base.py:326(ndim)
#         1    0.000    0.000    0.000    0.000 blocks.py:213(make_block)
#         1    0.000    0.000    0.000    0.000 utils.py:125(check_setitem_lengths)
#         3    0.000    0.000    0.000    0.000 std.py:113(__exit__)
#         1    0.000    0.000    0.004    0.004 widget_float.py:23(__init__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:53(_commit_removals)
#         1    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 base.py:46(__len__)
#        12    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:27(__exit__)
#         2    0.000    0.000    0.000    0.000 nanops.py:353(_na_ok_dtype)
#         1    0.000    0.000    0.000    0.000 indexing.py:777(_ensure_listlike_indexer)
#         5    0.000    0.000    0.000    0.000 common.py:1322(is_1d_only_ea_dtype)
#         1    0.000    0.000    0.000    0.000 indexing.py:287(loc)
#         4    0.000    0.000    0.000    0.000 pathlib.py:600(_from_parsed_parts)
#         1    0.000    0.000    0.000    0.000 warnings.py:165(simplefilter)
#         6    0.000    0.000    0.000    0.000 inference.py:294(<genexpr>)
#         3    0.000    0.000    0.000    0.000 std.py:226(__init__)
#         2    0.000    0.000    0.000    0.000 threading.py:273(_release_save)
#         8    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 displaypub.py:43(_validate_data)
#         2    0.000    0.000    0.000    0.000 missing.py:106(isna)
#         1    0.000    0.000    0.008    0.008 <decorator-gen-4>:1(__call__)
#         2    0.000    0.000    0.000    0.000 std.py:1153(_comparable)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:169(__enter__)
#         1    0.000    0.000    0.000    0.000 csvs.py:130(_get_index_label_flat)
#         1    0.000    0.000    0.000    0.000 format.py:791(truncate)
#         5    0.000    0.000    0.000    0.000 common.py:152(<lambda>)
#         2    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 nanops.py:82(check)
#         1    0.000    0.000    0.000    0.000 std.py:153(__init__)
#         1    0.000    0.000    0.000    0.000 construction.py:616(_extract_index)
#         3    0.000    0.000    0.000    0.000 csvs.py:104(header)
#         2    0.000    0.000    0.000    0.000 nanops.py:220(_maybe_get_mask)
#         1    0.000    0.000    0.000    0.000 zmqshell.py:90(_hooks)
#         1    0.000    0.000    0.000    0.000 csvs.py:179(data_index)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#         1    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:198(cb)
#         2    0.000    0.000    0.000    0.000 threading.py:276(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 typing.py:306(inner)
#         1    0.000    0.000    0.000    0.000 blocks.py:350(_split_op_result)
#         1    0.000    0.000    0.000    0.000 codecs.py:186(__init__)
#         4    0.000    0.000    0.000    0.000 common.py:705(<lambda>)
#         1    0.000    0.000    0.000    0.000 base.py:2107(_can_hold_na)
#         5    0.000    0.000    0.000    0.000 common.py:147(classes_and_not_datetimelike)
#         1    0.000    0.000    0.003    0.003 common.py:137(__exit__)
#         1    0.000    0.000    0.000    0.000 csvs.py:204(_need_to_save_header)
#         1    0.000    0.000    0.000    0.000 nanops.py:472(newfunc)
#         1    0.000    0.000    0.000    0.000 series.py:5540(isna)
#         2    0.000    0.000    0.000    0.000 construction.py:636(_sanitize_non_ordered)
#         4    0.000    0.000    0.000    0.000 {method 'co_lines' of 'code' objects}
#         4    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#         1    0.000    0.000    0.000    0.000 managers.py:1813(_consolidate_check)
#         1    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 generic.py:11493(sum)
#         1    0.000    0.000    0.000    0.000 generic.py:4358(_is_view)
#         2    0.000    0.000    0.000    0.000 threading.py:267(__exit__)
#         1    0.000    0.000    0.000    0.000 utils.py:156(__init__)
#         2    0.000    0.000    0.000    0.000 pathlib.py:853(__truediv__)
#         1    0.000    0.000    0.000    0.000 posixpath.py:377(abspath)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1038(_gcd_import)
#         3    0.000    0.000    0.000    0.000 common.py:1240(<lambda>)
#         1    0.000    0.000    0.000    0.000 common.py:1103(_maybe_memory_map)
#         1    0.000    0.000    0.000    0.000 widget.py:653(on_displayed)
#         1    0.000    0.000    0.000    0.000 _monitor.py:94(report)
#         1    0.000    0.000    0.000    0.000 managers.py:1805(is_consolidated)
#         4    0.000    0.000    0.000    0.000 managers.py:1944(_block)
#        12    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 std.py:682(<setcomp>)
#        13    0.000    0.000    0.000    0.000 traitlets.py:1335(ignore)
#         1    0.000    0.000    0.000    0.000 utils.py:64(is_list_like_indexer)
#         1    0.000    0.000    0.000    0.000 widget.py:217(register_callback)
#         1    0.000    0.000    0.000    0.000 construction.py:476(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 format.py:734(_calc_max_rows_fitted)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:216(_lock_unlock_module)
#         1    0.000    0.000    0.000    0.000 std.py:760(get_lock)
#         1    0.000    0.000    0.000    0.000 widget_float.py:41(_validate_min)
#        11    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 hooks.py:168(pre_run_code_hook)
#         3    0.000    0.000    0.000    0.000 flags.py:53(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 base.py:359(size)
#         3    0.000    0.000    0.000    0.000 blocks.py:479(dtype)
#         1    0.000    0.000    0.000    0.000 cast.py:767(infer_dtype_from)
#         1    0.000    0.000    0.000    0.000 format.py:689(_initialize_columns)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:165(__init__)
#         1    0.000    0.000    0.000    0.000 csvs.py:112(_initialize_index_label)
#         2    0.000    0.000    0.000    0.000 common.py:367(apply_if_callable)
#         1    0.000    0.000    0.000    0.000 widget.py:55(<listcomp>)
#         1    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#         1    0.000    0.000    0.000    0.000 format.py:425(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         3    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 function.py:60(__call__)
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup}
#         1    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 managers.py:280(arrays)
#         3    0.000    0.000    0.000    0.000 generic.py:338(attrs)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.000    0.000 os.py:759(decode)
#         1    0.000    0.000    0.000    0.000 base.py:931(dtype)
#         1    0.000    0.000    0.000    0.000 format.py:723(_calc_max_cols_fitted)
#         6    0.000    0.000    0.000    0.000 generic.py:359(flags)
#         3    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         2    0.000    0.000    0.000    0.000 format.py:767(_is_in_terminal)
#         8    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISLNK}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:968(_sanity_check)
#         1    0.000    0.000    0.000    0.000 formatters.py:359(_check_return)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:21(__enter__)
#         1    0.000    0.000    0.000    0.000 csvs.py:163(_initialize_chunksize)
#         1    0.000    0.000    0.000    0.000 managers.py:1823(_consolidate_inplace)
#         6    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 series.py:783(__len__)
#         1    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#         4    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         2    0.000    0.000    0.000    0.000 utils.py:139(__getattr__)
#         1    0.000    0.000    0.000    0.000 common.py:499(get_compression_method)
#         2    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#         1    0.000    0.000    0.000    0.000 inference.py:99(is_file_like)
#         2    0.000    0.000    0.000    0.000 threading.py:279(_is_owned)
#         4    0.000    0.000    0.000    0.000 multiarray.py:1080(copyto)
#         1    0.000    0.000    0.000    0.000 base.py:881(__array__)
#         1    0.000    0.000    0.000    0.000 indexing.py:148(iloc)
#         2    0.000    0.000    0.000    0.000 pathlib.py:94(join_parsed_parts)
#         1    0.000    0.000    0.000    0.000 csvs.py:134(_initialize_quotechar)
#         2    0.000    0.000    0.000    0.000 utils.py:222(__eq__)
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 _methods.py:47(_sum)
#         3    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#         1    0.000    0.000    0.000    0.000 indexing.py:2565(is_nested_tuple)
#         1    0.000    0.000    0.000    0.000 common.py:351(is_timedelta64_dtype)
#         3    0.000    0.000    0.000    0.000 series.py:574(_constructor)
#         1    0.000    0.000    0.000    0.000 generic.py:4161(_check_is_chained_assignment_possible)
#         1    0.000    0.000    0.000    0.000 nanops.py:1500(_maybe_null_out)
#         1    0.000    0.000    0.000    0.000 format.py:665(_initialize_sparsify)
#         1    0.000    0.000    0.000    0.000 format.py:1025(__init__)
#         1    0.000    0.000    0.000    0.000 generic.py:4176(_check_setitem_copy)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         1    0.000    0.000    0.000    0.000 cast.py:1750(np_can_hold_element)
#         1    0.000    0.000    0.000    0.000 inspect.py:191(isclass)
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup_error}
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:17(__init__)
#         1    0.000    0.000    0.000    0.000 managers.py:292(<listcomp>)
#         1    0.000    0.000    0.000    0.000 indexing.py:2528(convert_missing_indexer)
#         1    0.000    0.000    0.000    0.000 blocks.py:2100(is_view)
#         1    0.000    0.000    0.000    0.000 utils.py:252(_is_utf)
#         1    0.000    0.000    0.000    0.000 construction.py:197(mgr_to_mgr)
#         1    0.000    0.000    0.000    0.000 widget_float.py:51(_validate_max)
#         4    0.000    0.000    0.000    0.000 series.py:1323(_clear_item_cache)
#         2    0.000    0.000    0.000    0.000 nanops.py:198(_get_fill_value)
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 pretty.py:305(_get_mro)
#         1    0.000    0.000    0.000    0.000 format.py:699(_initialize_colspace)
#         1    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISDIR}
#         1    0.000    0.000    0.000    0.000 utils.py:282(_screen_shape_wrapper)
#         2    0.000    0.000    0.000    0.000 base.py:778(is_)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         2    0.000    0.000    0.000    0.000 parse.py:111(_noop)
#         1    0.000    0.000    0.000    0.000 format.py:633(is_truncated_horizontally)
#         1    0.000    0.000    0.000    0.000 format.py:670(_initialize_formatters)
#         2    0.000    0.000    0.000    0.000 managers.py:233(items)
#         1    0.000    0.000    0.000    0.000 _dtype.py:330(_name_includes_bit_suffix)
#         2    0.000    0.000    0.000    0.000 managers.py:333(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 formatters.py:274(_get_type)
#         1    0.000    0.000    0.000    0.000 csvs.py:100(decimal)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 std.py:167(colour)
#         1    0.000    0.000    0.000    0.000 utils.py:112(__format__)
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 managers.py:982(__init__)
#         4    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 base.py:1582(name)
#         4    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 base.py:4937(_values)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         1    0.000    0.000    0.000    0.000 csvs.py:108(index)
#         1    0.000    0.000    0.000    0.000 csvs.py:92(na_rep)
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 base.py:683(_constructor)
#         1    0.000    0.000    0.000    0.000 format.py:637(is_truncated_vertically)
#         1    0.000    0.000    0.000    0.000 managers.py:1838(ndim)
#         1    0.000    0.000    0.000    0.000 managers.py:1996(index)
#         1    0.000    0.000    0.000    0.000 common.py:134(__enter__)
#         1    0.000    0.000    0.000    0.000 format.py:753(_adjust_max_rows)
#         1    0.000    0.000    0.000    0.000 csvs.py:96(float_format)
#         1    0.000    0.000    0.000    0.000 std.py:163(colour)
#         1    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 indexing.py:1160(_has_valid_setitem_indexer)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#         1    0.000    0.000    0.000    0.000 jsonutil.py:46(encode_images)
# '\\n'

# %% [markdown]
# ## Chinese

# %%
# !pip3 install jieba zhon nltk pandas
# Out:
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (0.42.1)
# Requirement already satisfied: zhon in /usr/local/lib/python3.10/dist-packages (2.0.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import jieba
import jieba.posseg as pseg
import pandas as pd
import re
from zhon.hanzi import punctuation
from nltk.corpus import stopwords

# Ensure nltk stopwords are downloaded
import nltk
nltk.download('stopwords')

# Load Chinese stop words
chinese_stop_words = stopwords.words('chinese')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def normalize_token(token):
    # Here we simply convert to lowercase for normalization
    # Additional normalization logic can be added as needed
    return token.lower()

def dictionary_form(token):
    # This function can be expanded to convert to a standard dictionary form
    # For now, we'll assume the token itself is its dictionary form
    return token

def process_text(text):
    cleaned_text = clean_text(text)
    words = pseg.cut(cleaned_text)

    data = []

    for word, flag in words:
        if word not in chinese_stop_words:
            data.append({
                'surface': word,
                'normalized': normalize_token(word),
                'dictionary': dictionary_form(word),
                'POS': flag
            })

    df = pd.DataFrame(data)
    return df

# %%
# Read the Chinese text document

# read all files into list in ./raw_sorted_policies/chinese_raw
chinese_policies = []
for filename in os.listdir('./raw_sorted_policies/chinese_raw'):
    with open(f'./raw_sorted_policies/chinese_raw/{filename}', 'r', encoding='utf-8') as f:
        chinese_policies.append(f.read())

print(len(chinese_policies))
# Out:
# 444

# %%
text = chinese_policies[0]
print(text)
# df = process_text(text)
# print(df)
# Out:
# 库洛游戏儿童个人信息保护政策 库洛游戏儿童个人信息保护政策 更新日期： 202 4 年6 月6 日 欢迎您使用库洛游戏提供的服务。 “库洛游戏”是指与您签署本协议的游戏服务的提供方——广州库洛科技有限公司（注册地址：广州市天河区棠下荷光三横路7号之一107房）及/或广州库洛数界科技有限公司（注册地址：广州市天河区棠下荷光三横路7号之一110之一房），在本协议中也称“我们”。 本政策系我们在 《库洛游戏个人信息保护政策》 基础上，针对儿童个人信息的加强保护所作的进一步补充说明。 本政策中 “儿童”特指不满十四周岁的未成年人 。 有关十四周岁以上（包括 14周岁）的用户的个人信息保护规则，请您查阅《库洛游戏个人信息保护政策》 予以了解。就儿童个人信息保护事宜，如本政策与 《库洛游戏个人信息保护政策》 存在不一致之处，以本政策为准；如本政策未约定，以 《库洛游戏个人信息保护政策》 为准。本政策所使用的全部术语，除本政策另有说明外，与 《库洛游戏用户协议》 、 《库洛游戏个人信息保护政策》 中的术语具有相同涵义。 如您为儿童的家长或其他监护人（以下统称 “监护人”），请您陪同您的孩子共同仔细完整阅读并理解本政策内容，如您为儿童用户，请要求您的监护人与您共同仔细完整阅读并理解本政策内容，尤其是以加粗、 添加下划线 等方式重点提示的条款 ，以清楚知悉在儿童接受或使用库洛游戏所提供的服务时，库洛游戏对儿童用户信息收集、存储、使用、共享的方式，以及儿童用户或其监护人对儿童个人信息享有的管理权利，进而在更好地了解库洛游戏所提供的服务的前提下根据儿童及其监护人的需求，由监护人对是否同意儿童接受服务，接受或使用何种服务做出适当的选择。 儿童个人信息的收集、使用、转移、披露等处理依法均应征得儿童监护人的同意。在未取得监护人同意的情形下，儿童不应擅自接受或使用库洛游戏所提供的服务，也不得自行向我们提供任何儿童个人信息或相关授权。 请您知悉、理解并同意，监护人于线上同意本政策，或儿童用户已接受或使用库洛游戏所提供的服务，视为儿童用户及其监护人理解并认同本政策所述的全部内容。 特别提醒您的是：不满十四周岁未成年人的个人信息属于敏感个人信息。请您充分、谨慎考虑后再选择是否提供或授权。 若您有任何问题、意见或建议，请查看本政策 “联系我们”载明的方式与我们联系。 本政策将帮助您了解以下内容： · 一、我们可能收集的儿童用户信息 · 二、儿童用户信息的使用、存储和保护 · 三、 儿童用户信息的管理 · 四、 SDK或其他类似的应用程序 · 五、 本政策的适用范围 · 六 、本政策的变更 · 七 、联系我们 一、我们可能收集的儿童用户信息 当儿童接受或使用库洛游戏所提供的服务时，库洛游戏将遵循正当必要、知情同意、目的明确、安全保障、依法利用的原则，出于实现优质服务提供及用户信息保护的目的，收集、存储、使用、转移、披露儿童有关个人信息。我们仅会收集经儿童监护人同意，或由监护人和儿童主动提供的与我们产品或服务有关的儿童个人信息， 所涉及产品、服务的业务功能及对应拟收集和使用的用户信息类型详情请见 《库洛游戏个人信息保护政策》 。如我们需要超出上述范围收集和使用儿童个人信息，我们将再次征得监护人的同意。同时，为证实监护人与儿童的监护关系，更好地保护儿童的合法权益，我们可能 需要监护人提供必要的信息资料，包括监护人真实姓名、身份证、户口本或其他监护关系证明、以及联系电话等有效联系方式 。 二、儿童用户信息的使用、存储和保护 1、儿童用户信息的使用。 我们可能使用儿童信息的具体场景和方式参见 《库洛游戏个人信息保护政策》 。我们不会超出前述范围使用儿童信息，除非我们另行征得儿童用户和其监护人的授权同意。 2、儿童用户信息的存储。 除 法律法规另有规定 外， 库洛游戏仅在出于向儿童用户提供服务的目的所必需的尽可能短的时间范围内存储儿童的信息。在儿童用户和其监护人取消授权或超出 前述 存储期限后，我们将会对儿童的用户信息做删除或匿名化处理。库洛游戏会将儿童的用户信息存储于中华人民共和国境内。如需跨境传输，我们将会征得儿童用户和其监护人的授权同意，并会按照国家网信部门及相关部门制定的标准进行安全评估，为儿童个人信息提供有效保护。 3、儿童用户信息的保护。 我们会在现有技术水平下尽全力保护儿童的个人信息安全可靠。库洛游戏将采取包括物理、技术、管理等层面的各项合理安全措施来保护儿童的数据及信息，防止信息的泄漏、丢失、毁损。既包括 SSL、信息加密存储、数据中心的访问控制、专用的网络通道及代理等技术措施，又包括员工或外包人员权限控制与管理、保密协议签署、公司保密制度制定等人员或制度管理措施。如不幸发生儿童个人信息安全事件，我们将按照法律法规的要求及时通过公告、短信、电话、邮件通知等方式向儿童用户和其监护人告知相关事件的基本情况、可能的不利影响、我们已经采取或即将采取的处理措施等以便尽快对儿童用户信息泄露予以补救。同时，我们还将按照监管部门的要求，主动上报相关事件的处理情况。 三、儿童用户信息的管理 儿童使用我们的游戏产品及服务期间，为了儿童用户和其监护人可以更加便捷地访问和管理信息，同时保障注销账户的权利，我们在游戏中为用户提供了相应的操作设置，儿童用户和其监护人可以按照 《库洛游戏个人信息保护政策》 或者游戏当中的指引进行操作。同时，您也可联系我们的客服，要求对儿童个人信息进行更正或删除。 四、 SDK或其他类似的应用程序 为实现相关服务目的，我们可能会接入第三方服务商提供的 SDK或其他类似的应用程序。目前，我们接入的第三方SDK服务商及其服务功能，所收集信息/开通的权限详情请见 《第三方个人信息共享清单》 。 第三方服务由相关的第三方负责运营，您在使用该等服务时须受第三方服务商自身的服务条款及隐私政策约束，而不适用于本政策。为更好地保障儿童的合法权益，建议儿童和监护人在儿童使用任何第三方 SDK类服务前先行仔细阅读第三方服务商的服务条款及隐私政策。如发现这些SDK或其他类似的应用程序存在风险时，建议儿童和监护人立即终止相关操作并及时与我们取得联系。 五、本政策的适用范围 除某些特定服务外，库洛游戏所提供的服务均适用本政策。 但某些特定服务有其自身隐私政策时，以该特定服务自身的隐私政策的特殊约定为准。 本政策不适用由其他公司或个人向儿童用户提供的服务。儿童用户使用该等第三方服务时须受其隐私政策约束，请监护人和儿童用户仔细查阅。 六、本政策的变更 我们保留不时更新或修改本政策的权利。我们会在本页面上发布对本政策所做的任何变更。但是未经儿童及其监护人明确同意，我们不会削减儿童及其监护人按照本政策所应享有的权利。 请儿童及其监护人仔细阅读变更后的本政策内容。如儿童及其监护人不同意经变更后的本政策，或对本政策修改、更新的内容有异议，儿童及其监护人可以选择停止使用或者注销账号。但请儿童及其监护人知悉，儿童及其监护人账号注销之前、停止使用本服务之前的行为和活动仍受本政策的约束。 对于重大变更，我们将通过显著方式通知或向儿童及其监护人发送电子邮件或以其他方式通知对本政策所做的变更。 重大、实质性变更的情形包括以下情形： （ 1）我们的服务模式发生重大变化，使得处理个人信息的目的、处理的个人信息类型、个人信息的使用方式发生重大变化； （ 2）儿童及其监护人参与个人信息处理方面的权利及其行使方式发生重大变化。 七、联系我们 我们已指定专人负责儿童个人信息保护事宜，若监护人和儿童用户对本政策，及在接受或使用我们的产品、服务过程中关于儿童个人信息保护事宜有任何问题、意见或建议 ，您可以通过以下方式与我们联系： A.通过点击游戏内的“反馈”按钮进入客服页面； B.如您是《战双帕弥什》游戏的用户，您还可以通过邮箱kefu@kurogames.com联系我们的客服； C.如您是《鸣潮》游戏的用户，您还可以通过邮箱mc_support@kurogames.com联系我们的客服； D. 通过库洛游戏 客服中心电话 0571-56855725 联系我们的客服 ； E.通过库洛 游戏 官网（www.kurogames.com）载明的方式与我们联系 ； F.寄件地址：广州市海珠区聚新街31号小米大厦14楼，邮编：510220。

# %%
# with open('chinese_text.txt', 'r', encoding='utf-8') as file:
#     text = file.read()

# # Process the text and get the DataFrame
# df = process_text(text)

# # Output the DataFrame
# print(df)
